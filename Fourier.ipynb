# %%
# This code is developed by Pooyan :D

# %% [markdown]
# # Assignment Tittle
# __Author__ : Pooyan oskouhi 400222003
# __Course__ : Undergraduate Numerical Analysis Course

# %% [markdown]
# # Problem
# Calculate the fourier series for function $f(x) = x^3$

# %%
from sympy import *

# %% [markdown]
# # Part a:
# First, we should calculate with 5 sentences.

# %%
x = symbols('x')
s = fourier_series(x**3, (x, -2, 2)).truncate(5)
s
# Out:
# (-192/pi**3 + 32/pi)*sin(pi*x/2)/2 + (-16/pi + 24/pi**3)*sin(pi*x)/2 + (-64/(9*pi**3) + 32/(3*pi))*sin(3*pi*x/2)/2 + (-8/pi + 3/pi**3)*sin(2*pi*x)/2 + (-192/(125*pi**3) + 32/(5*pi))*sin(5*pi*x/2)/2

# %%
f = x**3
s = fourier_series(f, (x, -2, 2))
s1 = s.truncate(5)
p = plot(f, s1, (x, -2, 2), show=False, legend=False)
p.show()

# %% [markdown]
# # Part b:
# Now we calculate with 11 sentences.

# %%
x = symbols('x')
s = fourier_series(x**3, (x, -2, 2)).truncate(11)
s
# Out:
# (-192/pi**3 + 32/pi)*sin(pi*x/2)/2 + (-16/pi + 24/pi**3)*sin(pi*x)/2 + (-64/(9*pi**3) + 32/(3*pi))*sin(3*pi*x/2)/2 + (-8/pi + 3/pi**3)*sin(2*pi*x)/2 + (-192/(125*pi**3) + 32/(5*pi))*sin(5*pi*x/2)/2 + (-16/(3*pi) + 8/(9*pi**3))*sin(3*pi*x)/2 + (-192/(343*pi**3) + 32/(7*pi))*sin(7*pi*x/2)/2 + (-4/pi + 3/(8*pi**3))*sin(4*pi*x)/2 + (-64/(243*pi**3) + 32/(9*pi))*sin(9*pi*x/2)/2 + (-16/(5*pi) + 24/(125*pi**3))*sin(5*pi*x)/2 + (-192/(1331*pi**3) + 32/(11*pi))*sin(11*pi*x/2)/2

# %%
f = x**3
s = fourier_series(f, (x, -2, 2))
s1 = s.truncate(11)
p = plot(f, s1, (x, -2, 2), show=False, legend=False)
p.show()

# %% [markdown]
# # Part c:
# Now 21 sentences.

# %%
x = symbols('x')
s = fourier_series(x**3, (x, -2, 2)).truncate(21)
s
# Out:
# (-192/pi**3 + 32/pi)*sin(pi*x/2)/2 + (-16/pi + 24/pi**3)*sin(pi*x)/2 + (-64/(9*pi**3) + 32/(3*pi))*sin(3*pi*x/2)/2 + (-8/pi + 3/pi**3)*sin(2*pi*x)/2 + (-192/(125*pi**3) + 32/(5*pi))*sin(5*pi*x/2)/2 + (-16/(3*pi) + 8/(9*pi**3))*sin(3*pi*x)/2 + (-192/(343*pi**3) + 32/(7*pi))*sin(7*pi*x/2)/2 + (-4/pi + 3/(8*pi**3))*sin(4*pi*x)/2 + (-64/(243*pi**3) + 32/(9*pi))*sin(9*pi*x/2)/2 + (-16/(5*pi) + 24/(125*pi**3))*sin(5*pi*x)/2 + (-192/(1331*pi**3) + 32/(11*pi))*sin(11*pi*x/2)/2 + (-8/(3*pi) + 1/(9*pi**3))*sin(6*pi*x)/2 + (-192/(2197*pi**3) + 32/(13*pi))*sin(13*pi*x/2)/2 + (-16/(7*pi) + 24/(343*pi**3))*sin(7*pi*x)/2 + (-64/(1125*pi**3) + 32/(15*pi))*sin(15*pi*x/2)/2 + (-2/pi + 3/(64*pi**3))*sin(8*pi*x)/2 + (-192/(4913*pi**3) + 32/(17*pi))*sin(17*pi*x/2)/2 + (-16/(9*pi) + 8/(243*pi**3))*sin(9*pi*x)/2 + (-192/(6859*pi**3) + 32/(19*pi))*sin(19*pi*x/2)/2 + (-8/(5*pi) + 3/(125*pi**3))*sin(10*pi*x)/2 + (-64/(3087*pi**3) + 32/(21*pi))*sin(21*pi*x/2)/2

# %%
f = x**3
s = fourier_series(f, (x, -2, 2))
s1 = s.truncate(21)
p = plot(f, s1, (x, -2, 2), show=False, legend=False)
p.show()

# %% [markdown]
# # Part d:
# Now 31 sentences.

# %%
x = symbols('x')
s = fourier_series(x**3, (x, -2, 2)).truncate(31)
s
# Out:
# (-192/pi**3 + 32/pi)*sin(pi*x/2)/2 + (-16/pi + 24/pi**3)*sin(pi*x)/2 + (-64/(9*pi**3) + 32/(3*pi))*sin(3*pi*x/2)/2 + (-8/pi + 3/pi**3)*sin(2*pi*x)/2 + (-192/(125*pi**3) + 32/(5*pi))*sin(5*pi*x/2)/2 + (-16/(3*pi) + 8/(9*pi**3))*sin(3*pi*x)/2 + (-192/(343*pi**3) + 32/(7*pi))*sin(7*pi*x/2)/2 + (-4/pi + 3/(8*pi**3))*sin(4*pi*x)/2 + (-64/(243*pi**3) + 32/(9*pi))*sin(9*pi*x/2)/2 + (-16/(5*pi) + 24/(125*pi**3))*sin(5*pi*x)/2 + (-192/(1331*pi**3) + 32/(11*pi))*sin(11*pi*x/2)/2 + (-8/(3*pi) + 1/(9*pi**3))*sin(6*pi*x)/2 + (-192/(2197*pi**3) + 32/(13*pi))*sin(13*pi*x/2)/2 + (-16/(7*pi) + 24/(343*pi**3))*sin(7*pi*x)/2 + (-64/(1125*pi**3) + 32/(15*pi))*sin(15*pi*x/2)/2 + (-2/pi + 3/(64*pi**3))*sin(8*pi*x)/2 + (-192/(4913*pi**3) + 32/(17*pi))*sin(17*pi*x/2)/2 + (-16/(9*pi) + 8/(243*pi**3))*sin(9*pi*x)/2 + (-192/(6859*pi**3) + 32/(19*pi))*sin(19*pi*x/2)/2 + (-8/(5*pi) + 3/(125*pi**3))*sin(10*pi*x)/2 + (-64/(3087*pi**3) + 32/(21*pi))*sin(21*pi*x/2)/2 + (-16/(11*pi) + 24/(1331*pi**3))*sin(11*pi*x)/2 
# ...

# %%
f = x**3
s = fourier_series(f, (x, -2, 2))
s1 = s.truncate(31)
p = plot(f, s1, (x, -2, 2), show=False, legend=False)
p.show()

# %% [markdown]
# # Part e:
# Now 41 sentences.

# %%
x = symbols('x')
s = fourier_series(x**3, (x, -2, 2)).truncate(41)
s
# Out:
# (-192/pi**3 + 32/pi)*sin(pi*x/2)/2 + (-16/pi + 24/pi**3)*sin(pi*x)/2 + (-64/(9*pi**3) + 32/(3*pi))*sin(3*pi*x/2)/2 + (-8/pi + 3/pi**3)*sin(2*pi*x)/2 + (-192/(125*pi**3) + 32/(5*pi))*sin(5*pi*x/2)/2 + (-16/(3*pi) + 8/(9*pi**3))*sin(3*pi*x)/2 + (-192/(343*pi**3) + 32/(7*pi))*sin(7*pi*x/2)/2 + (-4/pi + 3/(8*pi**3))*sin(4*pi*x)/2 + (-64/(243*pi**3) + 32/(9*pi))*sin(9*pi*x/2)/2 + (-16/(5*pi) + 24/(125*pi**3))*sin(5*pi*x)/2 + (-192/(1331*pi**3) + 32/(11*pi))*sin(11*pi*x/2)/2 + (-8/(3*pi) + 1/(9*pi**3))*sin(6*pi*x)/2 + (-192/(2197*pi**3) + 32/(13*pi))*sin(13*pi*x/2)/2 + (-16/(7*pi) + 24/(343*pi**3))*sin(7*pi*x)/2 + (-64/(1125*pi**3) + 32/(15*pi))*sin(15*pi*x/2)/2 + (-2/pi + 3/(64*pi**3))*sin(8*pi*x)/2 + (-192/(4913*pi**3) + 32/(17*pi))*sin(17*pi*x/2)/2 + (-16/(9*pi) + 8/(243*pi**3))*sin(9*pi*x)/2 + (-192/(6859*pi**3) + 32/(19*pi))*sin(19*pi*x/2)/2 + (-8/(5*pi) + 3/(125*pi**3))*sin(10*pi*x)/2 + (-64/(3087*pi**3) + 32/(21*pi))*sin(21*pi*x/2)/2 + (-16/(11*pi) + 24/(1331*pi**3))*sin(11*pi*x)/2 
# ...

# %%
f = x**3
s = fourier_series(f, (x, -2, 2))
s1 = s.truncate(41)
p = plot(f, s1, (x, -2, 2), show=False, legend=False)
p.show()

# %% [markdown]
# # Part f:
# Now 71 sentences.

# %%
x = symbols('x')
s = fourier_series(x**3, (x, -2, 2)).truncate(71)
s
# Out:
# (-192/pi**3 + 32/pi)*sin(pi*x/2)/2 + (-16/pi + 24/pi**3)*sin(pi*x)/2 + (-64/(9*pi**3) + 32/(3*pi))*sin(3*pi*x/2)/2 + (-8/pi + 3/pi**3)*sin(2*pi*x)/2 + (-192/(125*pi**3) + 32/(5*pi))*sin(5*pi*x/2)/2 + (-16/(3*pi) + 8/(9*pi**3))*sin(3*pi*x)/2 + (-192/(343*pi**3) + 32/(7*pi))*sin(7*pi*x/2)/2 + (-4/pi + 3/(8*pi**3))*sin(4*pi*x)/2 + (-64/(243*pi**3) + 32/(9*pi))*sin(9*pi*x/2)/2 + (-16/(5*pi) + 24/(125*pi**3))*sin(5*pi*x)/2 + (-192/(1331*pi**3) + 32/(11*pi))*sin(11*pi*x/2)/2 + (-8/(3*pi) + 1/(9*pi**3))*sin(6*pi*x)/2 + (-192/(2197*pi**3) + 32/(13*pi))*sin(13*pi*x/2)/2 + (-16/(7*pi) + 24/(343*pi**3))*sin(7*pi*x)/2 + (-64/(1125*pi**3) + 32/(15*pi))*sin(15*pi*x/2)/2 + (-2/pi + 3/(64*pi**3))*sin(8*pi*x)/2 + (-192/(4913*pi**3) + 32/(17*pi))*sin(17*pi*x/2)/2 + (-16/(9*pi) + 8/(243*pi**3))*sin(9*pi*x)/2 + (-192/(6859*pi**3) + 32/(19*pi))*sin(19*pi*x/2)/2 + (-8/(5*pi) + 3/(125*pi**3))*sin(10*pi*x)/2 + (-64/(3087*pi**3) + 32/(21*pi))*sin(21*pi*x/2)/2 + (-16/(11*pi) + 24/(1331*pi**3))*sin(11*pi*x)/2 
# ...

# %%
f = x**3
s = fourier_series(f, (x, -2, 2))
s1 = s.truncate(71)
p = plot(f, s1, (x, -2, 2), show=False, legend=False)
p.show()

# %% [markdown]
# # Part g:
# Now 91 sentences.

# %%
x = symbols('x')
s = fourier_series(x**3, (x, -2, 2)).truncate(91)
s
# Out:
# (-192/pi**3 + 32/pi)*sin(pi*x/2)/2 + (-16/pi + 24/pi**3)*sin(pi*x)/2 + (-64/(9*pi**3) + 32/(3*pi))*sin(3*pi*x/2)/2 + (-8/pi + 3/pi**3)*sin(2*pi*x)/2 + (-192/(125*pi**3) + 32/(5*pi))*sin(5*pi*x/2)/2 + (-16/(3*pi) + 8/(9*pi**3))*sin(3*pi*x)/2 + (-192/(343*pi**3) + 32/(7*pi))*sin(7*pi*x/2)/2 + (-4/pi + 3/(8*pi**3))*sin(4*pi*x)/2 + (-64/(243*pi**3) + 32/(9*pi))*sin(9*pi*x/2)/2 + (-16/(5*pi) + 24/(125*pi**3))*sin(5*pi*x)/2 + (-192/(1331*pi**3) + 32/(11*pi))*sin(11*pi*x/2)/2 + (-8/(3*pi) + 1/(9*pi**3))*sin(6*pi*x)/2 + (-192/(2197*pi**3) + 32/(13*pi))*sin(13*pi*x/2)/2 + (-16/(7*pi) + 24/(343*pi**3))*sin(7*pi*x)/2 + (-64/(1125*pi**3) + 32/(15*pi))*sin(15*pi*x/2)/2 + (-2/pi + 3/(64*pi**3))*sin(8*pi*x)/2 + (-192/(4913*pi**3) + 32/(17*pi))*sin(17*pi*x/2)/2 + (-16/(9*pi) + 8/(243*pi**3))*sin(9*pi*x)/2 + (-192/(6859*pi**3) + 32/(19*pi))*sin(19*pi*x/2)/2 + (-8/(5*pi) + 3/(125*pi**3))*sin(10*pi*x)/2 + (-64/(3087*pi**3) + 32/(21*pi))*sin(21*pi*x/2)/2 + (-16/(11*pi) + 24/(1331*pi**3))*sin(11*pi*x)/2 
# ...

# %%
f = x**3
s = fourier_series(f, (x, -2, 2))
s1 = s.truncate(71)
p = plot(f, s1, (x, -2, 2), show=False, legend=False)
p.show()

# %%
f = x**3
s = fourier_series(f, (x, -10, 10))
s1 = s.truncate(101)
p = plot(f, s1, (x, -10, 10), show=False, legend=False)
p.show()

# %% [markdown]
# # Conclusion
# We can see that the global approximate function is going to be nearer to real function if we calculate more sentences of Fourier series.

# %%
# Hope you like it ;)
